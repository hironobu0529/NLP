# %%
cd ..
# Out:
# /home/hnakamura/nlp/nestedDependency

# %%
# -*- coding: utf-8 -*-
import spacy
import pandas as pd
import glob
import os
import re
from exJapaneseFeatures import JapaneseFeatureExtractor

from functools import lru_cache
from typing import Iterable, List, Tuple, Optional

Edge = Tuple[int, int]

# -----------------------
# ユーティリティ
# -----------------------
def _orientation(a: int, b: int) -> int:
    """右向き:+1, 左向き:-1（a==b は呼び出し元で排除）"""
    return 1 if a < b else -1

def _norm(a: int, b: int) -> Tuple[int, int]:
    """包含判定用に (L,R) 化（L<R）"""
    return (a, b) if a < b else (b, a)

def _strictly_contains_LR(L1: int, R1: int, L2: int, R2: int) -> bool:
    """交差・境界一致を排除した純粋な包含: L1 < L2 < R2 < R1"""
    return (L1 < L2) and (R2 < R1)

def _contains(outer: Edge, inner: Edge, same_direction_only: bool) -> bool:
    s1, t1 = outer; s2, t2 = inner
    if s1 == t1 or s2 == t2:
        return False  # 退化区間は含めない
    if same_direction_only and _orientation(s1, t1) != _orientation(s2, t2):
        return False
    L1, R1 = _norm(s1, t1); L2, R2 = _norm(s2, t2)
    return _strictly_contains_LR(L1, R1, L2, R2)

def _validate_edges(arrows: Iterable[Edge], *, max_edges: Optional[int] = None) -> List[Edge]:
    """軽い入力検証＋退化区間の除外＋重複の除去（順序保持）"""
    unique = []
    seen = set()
    try:
        for e in arrows:
            if not (isinstance(e, tuple) and len(e) == 2 and all(isinstance(x, int) for x in e)):
                raise TypeError(f"Edge must be tuple(int,int), got: {e}")
            if e[0] == e[1]:
                # 退化区間はスキップ（警告は出さない/必要なら print する）
                continue
            if e not in seen:
                unique.append(e); seen.add(e)
            if max_edges is not None and len(unique) > max_edges:
                # 防御的にサイズ上限（超えたら途中で返す）
                break
    except Exception as ex:
        raise ValueError(f"Invalid arrows input: {ex}") from ex
    return unique

def _extract_edges_from_doc(doc) -> List[Edge]:
    return [(tok.i, tok.head.i) for tok in doc if tok.head != tok]

def find_sentence_with_max_nesting_depth(
    sentences: List[str],
    nlp,
    same_direction_only: bool = True
):
    """
    与えられた文リストから、包摂関係の"最大深さ"が最大となる
    （文, 最大深さ, エッジ数）のタプルを返す。
    該当なしなら (None, 0, 0)。
    """
    best_sent = None
    best_depth = 0
    best_edges = 0

    for s in sentences:
        s = (s or "").strip()
        if not s:
            continue
        try:
            doc = nlp(s)
            arrows = _extract_edges_from_doc(doc)
            if not arrows:
                continue
            depth = max_interval_nesting_depth(arrows, same_direction_only=same_direction_only)
        except Exception as e:
            print(f"[error] max-depth calc failed: {e} :: {s[:40]}...")
            continue

        if depth > best_depth:
            best_depth = depth
            best_sent = s
            best_edges = len(arrows)

    return best_sent, best_depth, best_edges


"""
2023/08/15
https://note.com/npaka/n/n5c3e4ca67956
https://dev.classmethod.jp/articles/try-parsing-using-ginza/
https://megagonlabs.github.io/ginza/
を参照。
UNDERPIN fileに対してGINZA analysisを実行してデータフレームを出力

2024/01/11
GINZA解析はexJapaneseFeatures.pyから引っ張ってくるように変更
解析チェックの関数を追加。

2024/01/26
GINZA: max_bytes=49149
長文すぎるとGinzaは解析できない。
しかし、arrowsが短すぎると構文解析できずにarrows＝[]となる。
そのため、以下のようにした。

Patient_linesを用いて、1応答ずつ解析。
arrowsが短すぎる場合にはdepths = 0　とする。

2025/08/12
修正。
fpath変数の不適切な使用を修正。
ディレクトリエラーに対処。
"""

def analyze_sentence(sentence, nlp):
    # 短い文の場合は features を 0 で初期化
    if len(sentence.strip()) == 0:
        return {"max_nesting_relation": 0, "max_nesting_depth": 0}
    try:
        # 日本語モデルをロード, nlp
        # 解析を実行
        doc = nlp(sentence)

        # 対象とする係り受け関係のリスト
        #target_dependencies = ['nsubj', 'acl', "advcl", "obj"]
        
        # =======================
        # 両方向の辺を抽出（係り受けラベルの選定なし）
        # =======================
        # ※ 元の処理を最小修正：片方向制限とdepフィルタを撤廃
        arrows = [(tok.i, tok.head.i) for tok in doc if tok.head != tok]

        if not arrows:
            # 矢印リストが空の場合は、features を 0 で返す
            return {"max_nesting_relation": 0, "max_nesting_depth": 0}

        # 各矢印についてnesting_relationを計算
        nesting_relations = calculate_nesting_relations(arrows)
        # 最大のnesting_relationを求める
        max_nesting_relation = max(nesting_relations) if nesting_relations else 0
        # 最大の入れ子構造の深さを求める
        max_nesting_depth = max(calculate_nesting_depth(arrows, start, end) for start, end in arrows)

        features = {
            "max_nesting_relation": max_nesting_relation,
            "max_nesting_depth": max_nesting_depth
        }
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return {"max_nesting_relation": 0, "max_nesting_depth": 0}
    return features


def analyze_text_and_get_max_features(sentence_list, nlp):
    # 最大値を格納するための変数を初期化
    max_nesting_depth = 0
    max_nesting_relation = 0
    # 合計値を格納するための変数を初期化
    total_nesting_depth = 0

    # リスト内の各文に対してanalyze_sentenceを実行
    for sentence in sentence_list:
        # トークンの数が5以上のもののみ次に進む
        tokens = [token for token in nlp(sentence)]
        if len(tokens) >= 5:
            features = analyze_sentence(sentence, nlp)
            # 最大値を更新
            max_nesting_depth = max(max_nesting_depth, features["max_nesting_depth"])
            max_nesting_relation = max(max_nesting_relation, features["max_nesting_relation"])
            # 合計値を更新
            total_nesting_depth += features["max_nesting_depth"]

    features = {
            "max_nesting_relation": max_nesting_relation,
            "max_nesting_depth": max_nesting_depth,
            "total_nesting_depth": total_nesting_depth  # 合計値を辞書に追加
        }
    return features

# -----------------------
# 包摂カウント
# -----------------------
def calculate_nesting_relations(arrows: Iterable[Edge], same_direction_only: bool = True) -> List[int]:
    unique = _validate_edges(arrows)
    if not unique:
        return []

    counts_unique = [0] * len(unique)
    for i, cur in enumerate(unique):
        outers = 0; inners = 0
        for j, other in enumerate(unique):
            if j == i:
                continue
            if _contains(other, cur, same_direction_only):
                outers += 1
            if _contains(cur, other, same_direction_only):
                inners += 1
        counts_unique[i] = outers + inners

    idx = {e: k for k, e in enumerate(unique)}
    # ★ 入力 arrows の順序に対応して返す（修正点）
    return [counts_unique[idx[e]] for e in _validate_edges(arrows)]

# -----------------------
# 包摂の最長鎖（最大深さ）
# -----------------------
def calculate_nesting_depth(
    arrows: Iterable[Edge],
    start: int,
    end: int,
    depth: int = 0,  # 互換のため残置（未使用）
    same_direction_only: bool = True
) -> int:
    """
    起点エッジ (start,end) から純粋包含（必要なら向き一致）の内側だけを辿った
    "入れ子鎖の最長長"を返す。
    """
    unique = tuple(_validate_edges(arrows))
    if not unique:
        return 0
    if start == end:
        raise ValueError("start and end must differ (degenerate edge).")

    start_edge = (start, end)
    # 起点が実エッジに存在しない場合は警告（解析としては非推奨だが計算は続行）
    if start_edge not in unique:
        print(f"[warn] start edge {start_edge} not in arrows; proceeding anyway.")

    @lru_cache(maxsize=None)
    def _max_chain_from(s: int, t: int) -> int:
        # s,t の内側だけを次に辿る
        best = 0
        for (a, b) in unique:
            if _contains((s, t), (a, b), same_direction_only):
                cand = 1 + _max_chain_from(a, b)
                if cand > best:
                    best = cand
        return best

    return _max_chain_from(*start_edge)

def max_interval_nesting_depth(arrows: Iterable[Edge], same_direction_only: bool = True) -> int:
    """
    文内の全エッジを起点として探索し、包摂の"最大深さ"を返す。
    交差・境界一致は排除。方向一致は same_direction_only で切替。
    """
    unique = tuple(_validate_edges(arrows))
    if not unique:
        return 0

    @lru_cache(maxsize=None)
    def _max_chain_from(s: int, t: int) -> int:
        best = 0
        for (a, b) in unique:
            if _contains((s, t), (a, b), same_direction_only):
                cand = 1 + _max_chain_from(a, b)
                if cand > best:
                    best = cand
        return best

    best_overall = 0
    for (s, t) in unique:
        best_overall = max(best_overall, _max_chain_from(s, t))
    return best_overall

    

def readPatientPart(file):
    with open(file, mode='r', encoding='utf-8') as f:
        lines = f.readlines()
        lines_strip = [line.rstrip() for line in lines]  # 改行文字を除く
        line_num = [i for i in range(len(lines_strip))]
        p_line_num = [i for i, moji in enumerate(lines_strip) if '●患者' in moji]  # 「患者」を含む行番号を取得
        d_line_num = [i for i, moji in enumerate(lines_strip) if '●医師' in moji]
        target_num = p_line_num
        for i in range(len(p_line_num)):
            values = [e for e in d_line_num if e > p_line_num[i]]
            if values:
                if p_line_num[i] == (min(values) - 1):
                    continue
                else:
                    add_num = [j for j in range(len(lines_strip)) if (p_line_num[i] < j < min(values))]
                    target_num = target_num + add_num
            else:
                larger_num = [y for y in line_num if (y > p_line_num[i])]
                target_num = target_num + larger_num
        target_num = sorted(target_num)
        patient_lines = [s.replace('●患者', '') if s.startswith('●患者') else s for s in
                         [moji for i, moji in enumerate(lines_strip) if i in target_num]]
        patient_lines = [re.sub("\(.+?\)", "", s) if '(' in s else s for s in patient_lines]
        return patient_lines


def fileSortForAnalaysisNestedDependency(path, dataframe, feature_extractor, nlp):
    # ディレクトリを移動
    os.chdir(path)
    file = [os.path.join(path, f) for f in os.listdir(path) if f.endswith('.txt')]
    print('file:',file)
    for i in range(len(file)):
        target1 = '.txt'
        target2 = 'Kana.txt'
        if ((target1 in file[i]) == True) or ((target2 in file[i]) == True):
            try:
                catch_id = re.findall(r'U[A-Z]{2}[0-9]{3}.[1-5].[1-3]', file[i])
                subid = catch_id[0][0:6]
                subvisit = catch_id[0][7]
                subpart = catch_id[0][9]
                print('file:', file[i])
                try:
                    # 修正: fpathをfile[i]に変更
                    PATIENT_lines = readPatientPart(file[i])
                    filtered_patient_lines = apply_filter_to_patient_lines(PATIENT_lines, nlp)
                    # 空行除去
                    filtered_patient_lines = [s for s in filtered_patient_lines if (s or "").strip()]

                    # ★ 各サブジェクトで「最大深さの1文」をプリント
                    max_sent, max_depth, max_edges = find_sentence_with_max_nesting_depth(
                        filtered_patient_lines, nlp, same_direction_only=True  # 必要なら True に
                    )
                    if max_sent is not None:
                        print(f"[MAX_NESTING_DEPTH] ID={subid} Visit={subvisit} Part={subpart} "
                              f"depth={max_depth} edges={max_edges}\n  SENT: {max_sent}")

                    # 既存の集計
                    features = analyze_text_and_get_max_features(filtered_patient_lines, nlp)
                    features_dependency = analyze_dependency(filtered_patient_lines, nlp)

                    dic = {'ID': subid, 'Visit': subvisit, 'Part': subpart}
                    dic.update(**features, **features_dependency)
                    print(dic)

                    df = pd.DataFrame(data=dic, index=['val', ])
                    dataframe = pd.concat([df, dataframe], axis=0)

                except Exception as e:
                    # 修正: fpathをfile[i]に変更
                    print(f"[error] inner processing failed for {file[i]}: {e}")

            except Exception as e:
                # 修正: fpathをfile[i]に変更
                print(f"[error] outer loop failure at {file[i]}: {e}")
    return dataframe


def checkFileAnalyzedOrNot(directory_path, dataframe):
    # dataframeからID, Visit, Partを読み取り、file_name = "ID-Visit_Part"を作成
    analyzed_file_list = [f"{row['ID']}-{row['Visit']}_{row['Part']}" for index, row in dataframe.iterrows()]

    # 正規表現パターン
    pattern = r'U[A-Z]{2}[0-9]{3}.[1-5].[1-3]'

    # '.txt' 形式のファイルのパスを格納するリスト
    all_txt_file = [os.path.join(directory_path, f) for f in os.listdir(directory_path) if f.endswith('.txt')]

    # ディレクトリ内の全てのファイルのパスを格納するリスト
    all_path = [os.path.join(directory_path, f) for f in os.listdir(directory_path)]

    # all_pathから正規表現にマッチするID部分を抽出し、リスト化
    all_id_list = []
    for path in all_path:
        match = re.search(pattern, path)
        if match:
            all_id_list.append(match.group(0))

    # all_pathに含まれ、all_txt_fileに含まれない要素のみを持つリスト
    rest_path_txt_all = [f for f in all_path if f not in all_txt_file]

    # all_id_listに含まれ、analyzed_file_listに含まれない要素のみを持つリスト
    rest_path_analyzed_all = [id for id in all_id_list if id not in analyzed_file_list]

    print("TXT Files:", all_txt_file)
    print("txtファイル数:", len(all_txt_file))
    # print("All Files:", all_path)
    print("rest files(all-.txt):", rest_path_txt_all)
    print("実際に解析対象となったファイル数:", len(analyzed_file_list))
    print("rest files(all-analyzed):", rest_path_analyzed_all)

    return rest_path_analyzed_all

def filtered_sentence(sentence, nlp):
    doc = nlp(sentence)
    # フィラー、"INTJ"、 "reparandum" 依存関係のトークンを除外
    filtered_tokens = [token.text for token in doc if
                       token.tag_ != "感動詞-フィラー" and token.pos_ != "INTJ"]
    result = ''.join(filtered_tokens)
    # 読点を削除
    result = result.replace("、", "")
    result = result.replace("。", "")
    return result

# 既存の関数とコードの後に追加
def apply_filter_to_patient_lines(patient_lines, nlp):
    # filtered_sentence 関数を使って各行を処理
    filtered_lines = [filtered_sentence(line, nlp) for line in patient_lines]
    return filtered_lines

def analyze_dependency(patient_lines, nlp):
    max_tree_heights = []
    total_distances = []
    num_leaves_list = []
    num_nodes_list = []
    total_tree_height = 0  # 木の高さの合計を格納する変数を初期化

    for sentence in patient_lines:
        if len(sentence.strip()) == 0:
            continue  # 空の文はスキップ
        
        try:
            doc = nlp(sentence)
        except Exception as e:
            print(f"nlp処理中にエラーが発生しました: {e}")
            continue  # エラーが発生した文はスキップして次へ

        max_depth = 0
        total_distance = 0
        child_counts = {token.i: 0 for token in doc}

        try:
            for token in doc:
                depth = 0
                current = token
                while current.head != current:
                    depth += 1
                    current = current.head
                    total_distance += 1
                max_depth = max(max_depth, depth)
                child_counts[current.i] += 1

            num_leaves = sum(1 for count in child_counts.values() if count == 0)
        except Exception as e:
            print(f"依存関係の計算中にエラーが発生しました: {e}")
            continue  # エラーが発生した文はスキップして次へ
        
        max_tree_heights.append(max_depth)
        total_distances.append(total_distance)
        num_leaves_list.append(num_leaves)
        num_nodes_list.append(len(doc))
        total_tree_height += max_depth  # 各文の最大深さ（木の高さ）を合計に追加
    
    # 集計
    try:
        total_num_nodes = sum(num_nodes_list)
        max_tree_height = max(max_tree_heights) if max_tree_heights else 0
        total_num_leaves = sum(num_leaves_list)
        total_distance = sum(total_distances)
    except Exception as e:
        print(f"集計中にエラーが発生しました: {e}")
        return {}  # エラーが発生した場合は空の辞書を返す

    return {
        "max_tree_height": max_tree_height,
        "total_num_nodes": total_num_nodes,
        "total_num_leaves": total_num_leaves,
        "total_distance": total_distance,
        "total_tree_height": total_tree_height  # 木の高さの合計を辞書に追加
    }

if __name__ == '__main__':
    # JapaneseFeatureExtractor インスタンスを作成
    feature_extractor = JapaneseFeatureExtractor()
    #nlp = feature_extractor.nlp_speech #話し言葉用
    nlp = feature_extractor.nlp_speech_CEJCminus # CEJCminus
    #nlp = feature_extractor.nlp #書き言葉用
    # 例の使用法
    sentence = "私はああそうだニュースは今日が徳川家康の誕生日だと伝えたようだね困ったものだなあと思ったものだよ私は彼が鹿だという話を彼から聞いた"
    features = analyze_sentence(sentence, nlp)
    print(features)

    #　例文解析
    text="これは例文です。"
    ex_features = analyze_sentence(text, nlp)  # sentenceを解析
    ex_dic = {'ID': 'example', 'Visit': 0, 'Part': 0}
    #ex_dic1 = countMorpheme(text)
    #ex_dic2 = countEntity(text)
    #ex_dic3 = countSyntaxFeatures(text)
    print("ex_features:", ex_features)
    ex_dic.update(**ex_features)
    ex_df = pd.DataFrame(data=ex_dic, index=['val',])
    print(ex_df)

    # UNDERPIN解析
    PATH = '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22'
    #　インスタンス生成は、pythonProject以下で行うようにすること。注意が必要。
    
    # 修正: ディレクトリが存在するかチェック
    if not os.path.isdir(PATH):
        print(f"Error: Directory {PATH} does not exist or is not accessible")
        exit(1)
    
    # 修正: ディレクトリに移動する前にパスの妥当性を確認
    try:
        os.chdir(PATH)
        print(f"Successfully changedo directory: {PATH}")
    except Exception as e:
        print(f"Error changing to directory {PATH}: {e}")
        exit(1)
    
    dataframe_answer = fileSortForAnalaysisNestedDependency(PATH, ex_df, feature_extractor,nlp)
    print('dataframe_answer:', dataframe_answer)
    dataframe_answer.to_csv('Dataframe_analyzeNestedDependency_integration_R7Aug12_RecordVoice_vf_CEJCminus.csv')
    print(checkFileAnalyzedOrNot(PATH, dataframe_answer))
    print("解析から外れたファイル数:", len(checkFileAnalyzedOrNot(PATH, dataframe_answer)))
# Out:
# {'max_nesting_relation': 15, 'max_nesting_depth': 3}
# ex_features: {'max_nesting_relation': 0, 'max_nesting_depth': 0}
#           ID  Visit  Part  max_nesting_relation  max_nesting_depth
# val  example      0     0                     0                  0
# Successfully changedo directory: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22
# file: ['/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM029-3_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM057-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM020-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM018-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM008-3_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM024-4_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM001-2_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM020-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM021-3_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM022-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM004-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM167-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM189-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM035-2_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM016-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM181-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM119-4_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKP029-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM040-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM139-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM085-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM048-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM029-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM201-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM021-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM025-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM015-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM036-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM011-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM049-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM212-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM042-4_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM019-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM062-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM004-4_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM122-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM078-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM025-3_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UNM003-3_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/USM001-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UNM002-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM024-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM070-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM072-5_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKP019-2_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM030-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM012-3_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM149-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6No ...
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM029-3_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UMM029 Visit=3 Part=2 depth=2 edges=15
#   SENT: でもおじさんなら特にやりたいことなんだなと思って
# {'ID': 'UMM029', 'Visit': '3', 'Part': '2', 'max_nesting_relation': 4, 'max_nesting_depth': 2, 'total_nesting_depth': 12, 'max_tree_height': 7, 'total_num_nodes': 228, 'total_num_leaves': 201, 'total_distance': 453, 'total_tree_height': 69}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM057-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM057 Visit=1 Part=3 depth=2 edges=59
#   SENT: まおやつか何かで出たのを真ん中の子が１つないんで隣の女の子が食べたんじゃないかということで疑ってたんだけどとな食べたのは隣の反対側の男の子が食べたっていうことですかね
# {'ID': 'UKM057', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 11, 'max_nesting_depth': 2, 'total_nesting_depth': 5, 'max_tree_height': 7, 'total_num_nodes': 151, 'total_num_leaves': 143, 'total_distance': 481, 'total_tree_height': 31}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM020-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UMM020 Visit=2 Part=1 depth=2 edges=16
#   SENT: だから友達からま今こういう状態であんま外も出れないんで
# {'ID': 'UMM020', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 8, 'max_nesting_depth': 2, 'total_nesting_depth': 116, 'max_tree_height': 6, 'total_num_nodes': 2792, 'total_num_leaves': 2341, 'total_distance': 3943, 'total_tree_height': 839}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM018-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM018 Visit=1 Part=1 depth=4 edges=38
#   SENT: で昔はよく喋ってた気がするんですけどでもやっぱりその高校を一回中退して引きこもりになったので多分そのタイミングかなって思いますね
# {'ID': 'UTM018', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 15, 'max_nesting_depth': 4, 'total_nesting_depth': 79, 'max_tree_height': 7, 'total_num_nodes': 1391, 'total_num_leaves': 1268, 'total_distance': 2835, 'total_tree_height': 333}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM008-3_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UBM008 Visit=3 Part=1 depth=2 edges=19
#   SENT: 安倍さんのは悪口を言うのはあんたお１回怒るかも分からんけどな
# {'ID': 'UBM008', 'Visit': '3', 'Part': '1', 'max_nesting_relation': 6, 'max_nesting_depth': 2, 'total_nesting_depth': 81, 'max_tree_height': 7, 'total_num_nodes': 2150, 'total_num_leaves': 1815, 'total_distance': 3231, 'total_tree_height': 696}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM024-4_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM024 Visit=4 Part=1 depth=2 edges=15
#   SENT: なんでちょっと上司とはその分平日や休もうねっていうことで
# {'ID': 'UAM024', 'Visit': '4', 'Part': '1', 'max_nesting_relation': 7, 'max_nesting_depth': 2, 'total_nesting_depth': 147, 'max_tree_height': 6, 'total_num_nodes': 3040, 'total_num_leaves': 2702, 'total_distance': 4911, 'total_tree_height': 816}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM001-2_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UBM001 Visit=2 Part=2 depth=1 edges=9
#   SENT: 何やったっけあの竹から生まれたね
# {'ID': 'UBM001', 'Visit': '2', 'Part': '2', 'max_nesting_relation': 2, 'max_nesting_depth': 1, 'total_nesting_depth': 2, 'max_tree_height': 4, 'total_num_nodes': 64, 'total_num_leaves': 55, 'total_distance': 91, 'total_tree_height': 19}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM020-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM020 Visit=1 Part=3 depth=2 edges=22
#   SENT: そこでともう１人の女の子に「私のドーナツ食べたでしょ」と問い詰めるような感じです
# {'ID': 'UTM020', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 8, 'max_nesting_depth': 2, 'total_nesting_depth': 14, 'max_tree_height': 8, 'total_num_nodes': 266, 'total_num_leaves': 246, 'total_distance': 585, 'total_tree_height': 61}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM021-3_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM021 Visit=3 Part=2 depth=2 edges=30
#   SENT: とあれはと詳しくって言われるとどこからしゃべっていいのか分かんないんですけれどもあの１人の美しい女の子がおりました
# {'ID': 'UTM021', 'Visit': '3', 'Part': '2', 'max_nesting_relation': 11, 'max_nesting_depth': 2, 'total_nesting_depth': 21, 'max_tree_height': 10, 'total_num_nodes': 452, 'total_num_leaves': 428, 'total_distance': 1140, 'total_tree_height': 93}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM022-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UBM022 Visit=1 Part=1 depth=2 edges=10
#   SENT: まあまあ何も言う事無しに今があります
# {'ID': 'UBM022', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 7, 'max_nesting_depth': 2, 'total_nesting_depth': 93, 'max_tree_height': 6, 'total_num_nodes': 2192, 'total_num_leaves': 1850, 'total_distance': 2980, 'total_tree_height': 650}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM004-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM004 Visit=1 Part=1 depth=2 edges=26
#   SENT: そうですねどちらかと言うと警備業と言ってもまこう皆さんがイメージしているこう立ってこう
# {'ID': 'UAM004', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 9, 'max_nesting_depth': 2, 'total_nesting_depth': 91, 'max_tree_height': 6, 'total_num_nodes': 2037, 'total_num_leaves': 1804, 'total_distance': 3359, 'total_tree_height': 549}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM167-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM167 Visit=1 Part=2 depth=2 edges=25
#   SENT: である日と何か舞踏その国のお城で何か舞踏会踊りのパーティーみたいなのがあって
# {'ID': 'UKM167', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 10, 'max_nesting_depth': 2, 'total_nesting_depth': 32, 'max_tree_height': 6, 'total_num_nodes': 568, 'total_num_leaves': 522, 'total_distance': 1028, 'total_tree_height': 135}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM189-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM189 Visit=1 Part=1 depth=3 edges=24
#   SENT: なのでこうそこにいる人たちに何か多分へらへらした態度で行くと多分怒られそうな
# {'ID': 'UKM189', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 9, 'max_nesting_depth': 3, 'total_nesting_depth': 99, 'max_tree_height': 8, 'total_num_nodes': 1967, 'total_num_leaves': 1727, 'total_distance': 3094, 'total_tree_height': 534}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM035-2_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM035 Visit=2 Part=2 depth=3 edges=63
#   SENT: である時あのお城であの舞踏会があるからって招待状が来たんで３人の娘に招待状が来たんですけどもお母さんは２人お姉さん２人を出してシンデレラは家にあの着るものがないっていうので出さなかったんですね
# {'ID': 'UKM035', 'Visit': '2', 'Part': '2', 'max_nesting_relation': 28, 'max_nesting_depth': 3, 'total_nesting_depth': 11, 'max_tree_height': 12, 'total_num_nodes': 265, 'total_num_leaves': 259, 'total_distance': 1221, 'total_tree_height': 43}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM016-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM016 Visit=1 Part=1 depth=4 edges=37
#   SENT: 娘ももう何かちょっとね用事でこう封筒封書でこう来たりする時があるんだけど娘が何か字見るのも嫌だとか言う夫の
# {'ID': 'UKM016', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 36, 'max_nesting_depth': 4, 'total_nesting_depth': 307, 'max_tree_height': 8, 'total_num_nodes': 5696, 'total_num_leaves': 5365, 'total_distance': 13188, 'total_tree_height': 1086}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM181-2_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM181 Visit=2 Part=3 depth=1 edges=14
#   SENT: シンデレラあの出身は何だったかな覚えてないんだけど
# {'ID': 'UKM181', 'Visit': '2', 'Part': '3', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 3, 'max_tree_height': 3, 'total_num_nodes': 69, 'total_num_leaves': 58, 'total_distance': 91, 'total_tree_height': 18}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM119-4_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM119 Visit=4 Part=2 depth=4 edges=79
#   SENT: でと都のそして満月の晩おじいさんたちに頼まれた都の兵士などがかぐや姫を守ろうとお屋敷を囲んでいる中月からお迎えが来てそのかぐや姫が連れていかれるのを頑張って阻止しようとしたけれども不思議な力で兵士たちがやられてしまい最終的にかぐや姫は月へと帰っていきました
# {'ID': 'UKM119', 'Visit': '4', 'Part': '2', 'max_nesting_relation': 26, 'max_nesting_depth': 4, 'total_nesting_depth': 19, 'max_tree_height': 11, 'total_num_nodes': 467, 'total_num_leaves': 449, 'total_distance': 1588, 'total_tree_height': 76}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKP029-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKP029 Visit=1 Part=2 depth=1 edges=7
#   SENT: シンデレラがどうしたらいいかな
# {'ID': 'UKP029', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 5, 'max_nesting_depth': 1, 'total_nesting_depth': 20, 'max_tree_height': 6, 'total_num_nodes': 370, 'total_num_leaves': 327, 'total_distance': 555, 'total_tree_height': 101}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM040-2_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM040 Visit=2 Part=3 depth=2 edges=17
#   SENT: これここの１つこの子に誰が食べたつって怒って聞いてる
# {'ID': 'UKM040', 'Visit': '2', 'Part': '3', 'max_nesting_relation': 7, 'max_nesting_depth': 2, 'total_nesting_depth': 12, 'max_tree_height': 7, 'total_num_nodes': 164, 'total_num_leaves': 153, 'total_distance': 406, 'total_tree_height': 41}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM139-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM139 Visit=1 Part=2 depth=1 edges=7
#   SENT: 出てきたわね何か
# {'ID': 'UKM139', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 2, 'max_tree_height': 3, 'total_num_nodes': 62, 'total_num_leaves': 51, 'total_distance': 72, 'total_tree_height': 16}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM085-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM085 Visit=2 Part=1 depth=2 edges=29
#   SENT: 隣の女の子に対してあなたが食べたのかあなたが取って隠したんではないかというふうに怒ってます
# {'ID': 'UKM085', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 15, 'max_nesting_depth': 2, 'total_nesting_depth': 21, 'max_tree_height': 8, 'total_num_nodes': 397, 'total_num_leaves': 371, 'total_distance': 962, 'total_tree_height': 87}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM048-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM048 Visit=1 Part=1 depth=3 edges=35
#   SENT: でまあそれは今から考えると子供生んで睡眠不足が大きな原因じゃなかったかというふうに思ってるけどもちょっと大変なことがあった
# {'ID': 'UKM048', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 54, 'max_nesting_depth': 3, 'total_nesting_depth': 180, 'max_tree_height': 10, 'total_num_nodes': 3747, 'total_num_leaves': 3479, 'total_distance': 9207, 'total_tree_height': 795}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM029-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UOM029 Visit=1 Part=1 depth=2 edges=21
#   SENT: 測るとと２枚入ってるよったらこういうふうに２枚入ってる場合とかあるから
# {'ID': 'UOM029', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 8, 'max_nesting_depth': 2, 'total_nesting_depth': 209, 'max_tree_height': 5, 'total_num_nodes': 4585, 'total_num_leaves': 3882, 'total_distance': 6412, 'total_tree_height': 1397}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM201-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM201 Visit=1 Part=1 depth=2 edges=25
#   SENT: ここ１カ月間はとまず２週最初の２週間はと仕事で在宅勤務で朝９時から５時
# {'ID': 'UKM201', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 13, 'max_nesting_depth': 2, 'total_nesting_depth': 84, 'max_tree_height': 7, 'total_num_nodes': 1907, 'total_num_leaves': 1672, 'total_distance': 3271, 'total_tree_height': 495}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM021-2_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UOM021 Visit=2 Part=3 depth=1 edges=8
#   SENT: これはもっと食べたいんだって感じ
# {'ID': 'UOM021', 'Visit': '2', 'Part': '3', 'max_nesting_relation': 2, 'max_nesting_depth': 1, 'total_nesting_depth': 2, 'max_tree_height': 5, 'total_num_nodes': 49, 'total_num_leaves': 45, 'total_distance': 113, 'total_tree_height': 14}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM025-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UGM025 Visit=1 Part=1 depth=2 edges=25
#   SENT: でその僕の行ってる作業所は生活訓練ともう一つが就労いこ就労継続支援Ｂ型なんで
# {'ID': 'UGM025', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 17, 'max_nesting_depth': 2, 'total_nesting_depth': 235, 'max_tree_height': 7, 'total_num_nodes': 4741, 'total_num_leaves': 4220, 'total_distance': 8305, 'total_tree_height': 1225}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM015-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UGM015 Visit=2 Part=1 depth=2 edges=28
#   SENT: でも自分としてはあの今まで起こったことなは何１つ無駄じゃなかったと感じてんですけどね
# {'ID': 'UGM015', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 10, 'max_nesting_depth': 2, 'total_nesting_depth': 135, 'max_tree_height': 9, 'total_num_nodes': 2706, 'total_num_leaves': 2423, 'total_distance': 4748, 'total_tree_height': 682}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM036-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UGM036 Visit=1 Part=2 depth=2 edges=15
#   SENT: まあそのまあ１回シンデレラが履いたガラスの靴を落として
# {'ID': 'UGM036', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 7, 'max_nesting_depth': 2, 'total_nesting_depth': 10, 'max_tree_height': 6, 'total_num_nodes': 183, 'total_num_leaves': 167, 'total_distance': 338, 'total_tree_height': 45}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM011-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UOM011 Visit=1 Part=3 depth=2 edges=16
#   SENT: ところが一つ真ん中のお皿のドーナツは一つしかありません
# {'ID': 'UOM011', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 11, 'max_nesting_depth': 2, 'total_nesting_depth': 15, 'max_tree_height': 9, 'total_num_nodes': 208, 'total_num_leaves': 196, 'total_distance': 551, 'total_tree_height': 50}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM049-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM049 Visit=1 Part=2 depth=2 edges=17
#   SENT: 息子なんですけれどもその子がやっぱり１歳になるとき初めて歩くとき
# {'ID': 'UAM049', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 6, 'max_nesting_depth': 2, 'total_nesting_depth': 15, 'max_tree_height': 5, 'total_num_nodes': 277, 'total_num_leaves': 245, 'total_distance': 472, 'total_tree_height': 81}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM212-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM212 Visit=1 Part=2 depth=3 edges=36
#   SENT: そうですね元々いわゆるフランスだかどこかのあの民話をまあモチーフにしたものなのでさん元々はサンドリヨンとかいう言い方をしたと
# {'ID': 'UKM212', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 13, 'max_nesting_depth': 3, 'total_nesting_depth': 8, 'max_tree_height': 7, 'total_num_nodes': 149, 'total_num_leaves': 143, 'total_distance': 419, 'total_tree_height': 23}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM042-4_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM042 Visit=4 Part=3 depth=1 edges=9
#   SENT: 実はこの子が食べちゃってるんで
# {'ID': 'UAM042', 'Visit': '4', 'Part': '3', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 4, 'max_tree_height': 5, 'total_num_nodes': 140, 'total_num_leaves': 124, 'total_distance': 224, 'total_tree_height': 44}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM019-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UOM019 Visit=2 Part=1 depth=2 edges=8
#   SENT: あとは１人朝早く起きた時は
# {'ID': 'UOM019', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 7, 'max_nesting_depth': 2, 'total_nesting_depth': 92, 'max_tree_height': 6, 'total_num_nodes': 2167, 'total_num_leaves': 1880, 'total_distance': 3216, 'total_tree_height': 659}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM062-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM062 Visit=1 Part=3 depth=1 edges=10
#   SENT: ２番目がまあ食べたいこの指さしてます
# {'ID': 'UAM062', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 1, 'max_nesting_depth': 1, 'total_nesting_depth': 2, 'max_tree_height': 3, 'total_num_nodes': 62, 'total_num_leaves': 51, 'total_distance': 80, 'total_tree_height': 19}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM004-4_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UMM004 Visit=4 Part=2 depth=2 edges=28
#   SENT: ある日そのくん住んでる国のお城で舞踏会が開かれることになりまして行きたいと思ったんですけど
# {'ID': 'UMM004', 'Visit': '4', 'Part': '2', 'max_nesting_relation': 10, 'max_nesting_depth': 2, 'total_nesting_depth': 14, 'max_tree_height': 7, 'total_num_nodes': 265, 'total_num_leaves': 247, 'total_distance': 577, 'total_tree_height': 64}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM122-2_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM122 Visit=2 Part=3 depth=1 edges=5
#   SENT: これ続いてるんですか
# {'ID': 'UKM122', 'Visit': '2', 'Part': '3', 'max_nesting_relation': 4, 'max_nesting_depth': 1, 'total_nesting_depth': 9, 'max_tree_height': 4, 'total_num_nodes': 180, 'total_num_leaves': 161, 'total_distance': 301, 'total_tree_height': 47}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM078-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM078 Visit=2 Part=1 depth=3 edges=26
#   SENT: それからあとはあのやっぱりこれも体操であの体のね柔軟性を維持するっていうような位置づけかな
# {'ID': 'UKM078', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 11, 'max_nesting_depth': 3, 'total_nesting_depth': 178, 'max_tree_height': 7, 'total_num_nodes': 2905, 'total_num_leaves': 2608, 'total_distance': 4935, 'total_tree_height': 761}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM025-3_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UMM025 Visit=3 Part=3 depth=3 edges=22
#   SENT: とまずこの真ん中の子は私のドーナッツ１人で１つ食べちゃった人がいるって怒って
# {'ID': 'UMM025', 'Visit': '3', 'Part': '3', 'max_nesting_relation': 19, 'max_nesting_depth': 3, 'total_nesting_depth': 17, 'max_tree_height': 7, 'total_num_nodes': 303, 'total_num_leaves': 288, 'total_distance': 921, 'total_tree_height': 69}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UNM003-3_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UNM003 Visit=3 Part=3 depth=3 edges=31
#   SENT: でまあ自転車に乗ってる人がその魚はおっきい魚釣れてるよって教えてくれてるけど気づいてないっていう感じの絵ですね
# {'ID': 'UNM003', 'Visit': '3', 'Part': '3', 'max_nesting_relation': 13, 'max_nesting_depth': 3, 'total_nesting_depth': 13, 'max_tree_height': 9, 'total_num_nodes': 197, 'total_num_leaves': 183, 'total_distance': 544, 'total_tree_height': 48}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/USM001-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=USM001 Visit=1 Part=1 depth=3 edges=54
#   SENT: と高校を出てからそうですねもう９年１０年ぐらい埼玉のほうで暮らしてるんですけど病気をしてからはもう病気をしてサトウ病院に通うようになってからは月１で帰ってきているので
# {'ID': 'USM001', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 13, 'max_nesting_depth': 3, 'total_nesting_depth': 60, 'max_tree_height': 9, 'total_num_nodes': 1321, 'total_num_leaves': 1248, 'total_distance': 3342, 'total_tree_height': 251}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UNM002-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UNM002 Visit=1 Part=2 depth=1 edges=10
#   SENT: 聞いたことあるけどあまりわガラスの靴履く
# {'ID': 'UNM002', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 4, 'max_nesting_depth': 1, 'total_nesting_depth': 11, 'max_tree_height': 6, 'total_num_nodes': 267, 'total_num_leaves': 230, 'total_distance': 415, 'total_tree_height': 71}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM024-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UMM024 Visit=1 Part=2 depth=3 edges=30
#   SENT: この下女のようなまあ女中さんというか家のそういうお掃除だとかそういうことをずっとやらされていた
# {'ID': 'UMM024', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 10, 'max_nesting_depth': 3, 'total_nesting_depth': 20, 'max_tree_height': 5, 'total_num_nodes': 382, 'total_num_leaves': 335, 'total_distance': 627, 'total_tree_height': 107}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM070-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM070 Visit=1 Part=3 depth=2 edges=41
#   SENT: とドーナツが２個１個２個で余っているようですけど真ん中の子が私のドーナツが１つしかないというようなことを隣の女の子に言っています
# {'ID': 'UKM070', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 5, 'max_nesting_depth': 2, 'total_nesting_depth': 13, 'max_tree_height': 6, 'total_num_nodes': 226, 'total_num_leaves': 211, 'total_distance': 564, 'total_tree_height': 54}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM072-5_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM072 Visit=5 Part=1 depth=2 edges=30
#   SENT: だけどかといってこうこういうことをし何だろうこの状態がいいとおも思ってるわけでもないしっていう感じ
# {'ID': 'UKM072', 'Visit': '5', 'Part': '1', 'max_nesting_relation': 14, 'max_nesting_depth': 2, 'total_nesting_depth': 63, 'max_tree_height': 7, 'total_num_nodes': 1911, 'total_num_leaves': 1657, 'total_distance': 3228, 'total_tree_height': 541}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKP019-2_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKP019 Visit=2 Part=2 depth=3 edges=227
#   SENT: とシンデレラのお母さんが亡くなってまま母が来てでまま母には連れ子がいてその３人のたしか３人だったと思う３人のお姉さんたちに３人のお姉さんたちとまま母とにいじめられてで舞踏会が行われることになってお姉さんたちは新しいドレスを買ってもらえたんだけどシンデレラはあなたは行かせないっていうか行っちゃだめうちのことをやりなさいって言われてそれでお姉さんたちとお母さんがお城へ行ってそれからと魔法使いがシンデレラのもとに現れてで古いぼろぼろの洋服をきれいなすてきなドレスに変えてくれてカボチャの馬車を用意してくれてでお城に連れてってくれてでそこで王子と出会い王子に声をかけられたんだよなそれでとダンスとかして１２時の鐘が鳴ってかえられな帰らなくてはいけないっていって帰るときにガラスの靴を片方忘れてってでお姉さんたちが帰る前に帰れたんだと思う
# {'ID': 'UKP019', 'Visit': '2', 'Part': '2', 'max_nesting_relation': 50, 'max_nesting_depth': 3, 'total_nesting_depth': 6, 'max_tree_height': 19, 'total_num_nodes': 350, 'total_num_leaves': 348, 'total_distance': 3022, 'total_tree_height': 33}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM030-2_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM030 Visit=2 Part=3 depth=2 edges=25
#   SENT: ところが真ん中の子が何かうっかりしてかおしゃべりよそ見をしているうちに１個がなくなりました
# {'ID': 'UKM030', 'Visit': '2', 'Part': '3', 'max_nesting_relation': 10, 'max_nesting_depth': 2, 'total_nesting_depth': 16, 'max_tree_height': 7, 'total_num_nodes': 364, 'total_num_leaves': 338, 'total_distance': 854, 'total_tree_height': 84}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM012-3_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM012 Visit=3 Part=1 depth=2 edges=22
#   SENT: １２時は１２時に寝ると思ってると大体１時前に寝れてる感じなんですね
# {'ID': 'UKM012', 'Visit': '3', 'Part': '1', 'max_nesting_relation': 13, 'max_nesting_depth': 2, 'total_nesting_depth': 222, 'max_tree_height': 8, 'total_num_nodes': 4895, 'total_num_leaves': 4341, 'total_distance': 8135, 'total_tree_height': 1345}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM149-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM149 Visit=1 Part=2 depth=3 edges=25
#   SENT: で最後にそのぴったりその靴にぴったりなシンデレラを見つける事ができて王子様と結婚して終わるという
# {'ID': 'UKM149', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 20, 'max_nesting_depth': 3, 'total_nesting_depth': 18, 'max_tree_height': 7, 'total_num_nodes': 353, 'total_num_leaves': 325, 'total_distance': 878, 'total_tree_height': 86}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM038-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM038 Visit=1 Part=1 depth=2 edges=40
#   SENT: あと覆面調査っていうのが仕事であるのでそれはもう客のふりしてちゃんとお金も払ってでそれをレポートで提出するっていう仕事があるんですよ
# {'ID': 'UKM038', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 22, 'max_nesting_depth': 2, 'total_nesting_depth': 384, 'max_tree_height': 8, 'total_num_nodes': 7025, 'total_num_leaves': 6340, 'total_distance': 13017, 'total_tree_height': 1767}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM162-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM162 Visit=1 Part=3 depth=2 edges=24
#   SENT: 湖のほとりでキャンプをキャンプっていうかデイキャンプピクニックをしているカップルと凧揚げをしている男の子
# {'ID': 'UKM162', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 6, 'max_nesting_depth': 2, 'total_nesting_depth': 6, 'max_tree_height': 8, 'total_num_nodes': 181, 'total_num_leaves': 168, 'total_distance': 507, 'total_tree_height': 51}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM163-3_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM163 Visit=3 Part=2 depth=4 edges=44
#   SENT: でまあ当然継母と娘は入らずで最後に残ってたシンデレラがああ嵌って嵌ったことでついにこのシンデレラは王子様と結婚するっていう結末になったというお話ですね
# {'ID': 'UKM163', 'Visit': '3', 'Part': '2', 'max_nesting_relation': 19, 'max_nesting_depth': 4, 'total_nesting_depth': 32, 'max_tree_height': 9, 'total_num_nodes': 595, 'total_num_leaves': 566, 'total_distance': 1557, 'total_tree_height': 121}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM003-5_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM003 Visit=5 Part=2 depth=1 edges=4
#   SENT: 話なんですけど
# {'ID': 'UAM003', 'Visit': '5', 'Part': '2', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 5, 'max_tree_height': 6, 'total_num_nodes': 108, 'total_num_leaves': 92, 'total_distance': 187, 'total_tree_height': 40}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM005-4_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM005 Visit=4 Part=2 depth=1 edges=12
#   SENT: 継母と２人のお姉さんと一緒に暮らしていて
# {'ID': 'UTM005', 'Visit': '4', 'Part': '2', 'max_nesting_relation': 10, 'max_nesting_depth': 1, 'total_nesting_depth': 13, 'max_tree_height': 7, 'total_num_nodes': 247, 'total_num_leaves': 231, 'total_distance': 563, 'total_tree_height': 60}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM022-2_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM022 Visit=2 Part=3 depth=1 edges=7
#   SENT: とおやつの時間になりました
# {'ID': 'UAM022', 'Visit': '2', 'Part': '3', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 14, 'max_tree_height': 5, 'total_num_nodes': 219, 'total_num_leaves': 191, 'total_distance': 356, 'total_tree_height': 69}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM006-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM006 Visit=2 Part=1 depth=3 edges=24
#   SENT: で上の子だけだったら一応こう今日疲れてるからって今日ちょっと休み休むって言うともう全然一人で
# {'ID': 'UTM006', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 16, 'max_nesting_depth': 3, 'total_nesting_depth': 168, 'max_tree_height': 7, 'total_num_nodes': 3385, 'total_num_leaves': 3042, 'total_distance': 6180, 'total_tree_height': 901}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM009-2_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM009 Visit=2 Part=2 depth=1 edges=12
#   SENT: おばあさんが川へ洗濯物をしていて
# {'ID': 'UAM009', 'Visit': '2', 'Part': '2', 'max_nesting_relation': 2, 'max_nesting_depth': 1, 'total_nesting_depth': 4, 'max_tree_height': 3, 'total_num_nodes': 157, 'total_num_leaves': 126, 'total_distance': 181, 'total_tree_height': 50}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM038-3_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM038 Visit=3 Part=3 depth=1 edges=12
#   SENT: と３人でおやつを食べようとしていますと
# {'ID': 'UAM038', 'Visit': '3', 'Part': '3', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 10, 'max_tree_height': 6, 'total_num_nodes': 172, 'total_num_leaves': 155, 'total_distance': 303, 'total_tree_height': 50}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM019-4_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM019 Visit=4 Part=2 depth=2 edges=17
#   SENT: でそこでは多分お役所のようなお仕事をしているところで
# {'ID': 'UAM019', 'Visit': '4', 'Part': '2', 'max_nesting_relation': 6, 'max_nesting_depth': 2, 'total_nesting_depth': 39, 'max_tree_height': 5, 'total_num_nodes': 577, 'total_num_leaves': 511, 'total_distance': 929, 'total_tree_height': 166}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM013-3_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM013 Visit=3 Part=2 depth=2 edges=21
#   SENT: 金融のまあなんだろうと投資のアドバイザーをしている真面目な男の人がいて
# {'ID': 'UAM013', 'Visit': '3', 'Part': '2', 'max_nesting_relation': 8, 'max_nesting_depth': 2, 'total_nesting_depth': 14, 'max_tree_height': 6, 'total_num_nodes': 267, 'total_num_leaves': 245, 'total_distance': 534, 'total_tree_height': 67}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM012-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM012 Visit=1 Part=3 depth=1 edges=7
#   SENT: なくなってんじゃねえのみたいな
# {'ID': 'UAM012', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 7, 'max_tree_height': 3, 'total_num_nodes': 205, 'total_num_leaves': 172, 'total_distance': 247, 'total_tree_height': 63}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM015-2_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM015 Visit=2 Part=2 depth=2 edges=24
#   SENT: シンデレラは簡単に言うと私もちょっと詳しいあの全然関係ないんですけど詳しくは分からないんですよシンデレラ
# {'ID': 'UTM015', 'Visit': '2', 'Part': '2', 'max_nesting_relation': 23, 'max_nesting_depth': 2, 'total_nesting_depth': 44, 'max_tree_height': 9, 'total_num_nodes': 761, 'total_num_leaves': 696, 'total_distance': 1753, 'total_tree_height': 177}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM032-4_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM032 Visit=4 Part=3 depth=2 edges=20
#   SENT: で湖の方ではヨットというか帆を張った船に乗ってる人たちが
# {'ID': 'UAM032', 'Visit': '4', 'Part': '3', 'max_nesting_relation': 8, 'max_nesting_depth': 2, 'total_nesting_depth': 22, 'max_tree_height': 7, 'total_num_nodes': 320, 'total_num_leaves': 292, 'total_distance': 650, 'total_tree_height': 88}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM010-5_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM010 Visit=5 Part=1 depth=3 edges=19
#   SENT: だから中国も特許はあの期間は許可ねえどできねえわけだ作らねえわけだ
# {'ID': 'UAM010', 'Visit': '5', 'Part': '1', 'max_nesting_relation': 8, 'max_nesting_depth': 3, 'total_nesting_depth': 93, 'max_tree_height': 6, 'total_num_nodes': 1845, 'total_num_leaves': 1589, 'total_distance': 2683, 'total_tree_height': 519}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM014-4_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UBM014 Visit=4 Part=3 depth=1 edges=11
#   SENT: この子のし皆二つずつついてんのを
# {'ID': 'UBM014', 'Visit': '4', 'Part': '3', 'max_nesting_relation': 4, 'max_nesting_depth': 1, 'total_nesting_depth': 19, 'max_tree_height': 5, 'total_num_nodes': 331, 'total_num_leaves': 275, 'total_distance': 432, 'total_tree_height': 105}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM008-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM008 Visit=2 Part=1 depth=3 edges=42
#   SENT: ただでもそういうのを専門にもうやってる人は東京都とか経済産業省のそういう審査をしてるところのつながりもあるのでポイントを知ってるんですよね
# {'ID': 'UKM008', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 30, 'max_nesting_depth': 3, 'total_nesting_depth': 342, 'max_tree_height': 9, 'total_num_nodes': 6828, 'total_num_leaves': 6317, 'total_distance': 14743, 'total_tree_height': 1495}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM001-3_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM001 Visit=3 Part=2 depth=3 edges=20
#   SENT: で実際そのしてすぐ王子様に会いに行くために人魚姫は陸に上がりました
# {'ID': 'UKM001', 'Visit': '3', 'Part': '2', 'max_nesting_relation': 7, 'max_nesting_depth': 3, 'total_nesting_depth': 30, 'max_tree_height': 6, 'total_num_nodes': 487, 'total_num_leaves': 426, 'total_distance': 835, 'total_tree_height': 154}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM179-2_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM179 Visit=2 Part=2 depth=3 edges=26
#   SENT: であまりにも楽しくてどれぐらい時間が経ったかがわからなくなった時にそろそろ帰ろうということになり
# {'ID': 'UKM179', 'Visit': '2', 'Part': '2', 'max_nesting_relation': 12, 'max_nesting_depth': 3, 'total_nesting_depth': 21, 'max_tree_height': 9, 'total_num_nodes': 384, 'total_num_leaves': 354, 'total_distance': 914, 'total_tree_height': 95}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM037-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM037 Visit=1 Part=2 depth=2 edges=27
#   SENT: それで多分まま母じゃなかったですかまま母がいてお姉さんがいて一生懸命意地悪されたんですよね
# {'ID': 'UKM037', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 16, 'max_nesting_depth': 2, 'total_nesting_depth': 15, 'max_tree_height': 8, 'total_num_nodes': 342, 'total_num_leaves': 329, 'total_distance': 992, 'total_tree_height': 58}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM183-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM183 Visit=1 Part=3 depth=2 edges=37
#   SENT: でこのこの真ん中の子子がこのとこの右の子にあなた食べたでしょって問いただしてるんですけどこの右の子は食べてないよって言ってて
# {'ID': 'UKM183', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 14, 'max_nesting_depth': 2, 'total_nesting_depth': 12, 'max_tree_height': 8, 'total_num_nodes': 285, 'total_num_leaves': 266, 'total_distance': 796, 'total_tree_height': 63}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM014-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM014 Visit=2 Part=1 depth=3 edges=26
#   SENT: まあ気が合う時っていうかまあそれはあの人も忙しいのでまあスケジュール合う時とかそんな感じ
# {'ID': 'UKM014', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 13, 'max_nesting_depth': 3, 'total_nesting_depth': 187, 'max_tree_height': 7, 'total_num_nodes': 4010, 'total_num_leaves': 3598, 'total_distance': 7315, 'total_tree_height': 974}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM165-2_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM165 Visit=2 Part=2 depth=3 edges=58
#   SENT: で王子様はそのシンデレラを探し求めてでシンデレラの落としていったまあガラスの靴を頼りに片方の靴を頼りにシンデレラをこう探し町中をこう探していてでようやく王子様が見つけることが出来てまあ晴れて結婚することに
# {'ID': 'UKM165', 'Visit': '2', 'Part': '2', 'max_nesting_relation': 34, 'max_nesting_depth': 3, 'total_nesting_depth': 17, 'max_tree_height': 9, 'total_num_nodes': 376, 'total_num_leaves': 364, 'total_distance': 1280, 'total_tree_height': 58}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM005-4_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM005 Visit=4 Part=2 depth=1 edges=6
#   SENT: 大きな桃が流れてきて
# {'ID': 'UAM005', 'Visit': '4', 'Part': '2', 'max_nesting_relation': 4, 'max_nesting_depth': 1, 'total_nesting_depth': 3, 'max_tree_height': 7, 'total_num_nodes': 96, 'total_num_leaves': 80, 'total_distance': 159, 'total_tree_height': 34}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM025-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM025 Visit=1 Part=2 depth=1 edges=10
#   SENT: でおばあさんを頼んできましたが
# {'ID': 'UAM025', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 1, 'max_tree_height': 3, 'total_num_nodes': 94, 'total_num_leaves': 75, 'total_distance': 104, 'total_tree_height': 31}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM024-3_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM024 Visit=3 Part=3 depth=1 edges=7
#   SENT: 食べようとしているんですが
# {'ID': 'UAM024', 'Visit': '3', 'Part': '3', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 14, 'max_tree_height': 5, 'total_num_nodes': 258, 'total_num_leaves': 220, 'total_distance': 382, 'total_tree_height': 90}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM020-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UBM020 Visit=2 Part=1 depth=2 edges=13
#   SENT: ただま今のやつはは無理してるいうことですね
# {'ID': 'UBM020', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 6, 'max_nesting_depth': 2, 'total_nesting_depth': 81, 'max_tree_height': 6, 'total_num_nodes': 2053, 'total_num_leaves': 1769, 'total_distance': 2946, 'total_tree_height': 604}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM150-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM150 Visit=1 Part=3 depth=1 edges=40
#   SENT: 少年が魚釣りしていたんですけど居眠りしちゃって魚はえさを食べちゃってでそれを知らせようとして男の子が橋の上から何か言ってます
# {'ID': 'UKM150', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 4, 'max_nesting_depth': 1, 'total_nesting_depth': 3, 'max_tree_height': 7, 'total_num_nodes': 83, 'total_num_leaves': 80, 'total_distance': 254, 'total_tree_height': 17}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM017-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM017 Visit=1 Part=2 depth=2 edges=44
#   SENT: そのこの靴に合う人がこの靴が合う人がこの靴がはける人がてぴったりぴったりの人が多分そのそのときにで出会ったお姫様なんのはずだということで
# {'ID': 'UTM017', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 16, 'max_nesting_depth': 2, 'total_nesting_depth': 16, 'max_tree_height': 6, 'total_num_nodes': 305, 'total_num_leaves': 275, 'total_distance': 619, 'total_tree_height': 80}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM014-3_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UBM014 Visit=3 Part=1 depth=2 edges=8
#   SENT: で最近その頭痛いっていうのは
# {'ID': 'UBM014', 'Visit': '3', 'Part': '1', 'max_nesting_relation': 8, 'max_nesting_depth': 2, 'total_nesting_depth': 119, 'max_tree_height': 7, 'total_num_nodes': 2501, 'total_num_leaves': 2171, 'total_distance': 3953, 'total_tree_height': 767}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM031-5_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM031 Visit=5 Part=2 depth=3 edges=18
#   SENT: でも今の人今皆さん定年後の生活なんて言われてる人たちって
# {'ID': 'UAM031', 'Visit': '5', 'Part': '2', 'max_nesting_relation': 10, 'max_nesting_depth': 3, 'total_nesting_depth': 54, 'max_tree_height': 7, 'total_num_nodes': 788, 'total_num_leaves': 720, 'total_distance': 1532, 'total_tree_height': 203}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM018-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM018 Visit=1 Part=1 depth=2 edges=13
#   SENT: あとあのそのいわファンクラブ入っててそのゆあのんの
# {'ID': 'UAM018', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 6, 'max_nesting_depth': 2, 'total_nesting_depth': 76, 'max_tree_height': 5, 'total_num_nodes': 1871, 'total_num_leaves': 1551, 'total_distance': 2515, 'total_tree_height': 571}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM038-4_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM038 Visit=4 Part=1 depth=1 edges=7
#   SENT: もうもう１個病院行ってから
# {'ID': 'UAM038', 'Visit': '4', 'Part': '1', 'max_nesting_relation': 7, 'max_nesting_depth': 1, 'total_nesting_depth': 26, 'max_tree_height': 5, 'total_num_nodes': 649, 'total_num_leaves': 515, 'total_distance': 787, 'total_tree_height': 214}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM028-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM028 Visit=2 Part=1 depth=2 edges=13
#   SENT: そこからはちょっとお金を使わなくなったんですけど
# {'ID': 'UAM028', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 9, 'max_nesting_depth': 2, 'total_nesting_depth': 102, 'max_tree_height': 6, 'total_num_nodes': 2276, 'total_num_leaves': 1983, 'total_distance': 3388, 'total_tree_height': 631}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM006-5_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM006 Visit=5 Part=3 depth=3 edges=85
#   SENT: 真ん中の女の子が恐らくよそ見をしている間にと男の子が内緒で一つ食べ真ん中の子のドーナツを食べてしまいで右の女の子に私のそれを気が付かなかった真ん中の女の子が右の女の子に私の分食べたでしょうと怒っていてでもそんなことしていない右の女の子は私は違うわっていうのを言っていて
# {'ID': 'UTM006', 'Visit': '5', 'Part': '3', 'max_nesting_relation': 27, 'max_nesting_depth': 3, 'total_nesting_depth': 9, 'max_tree_height': 7, 'total_num_nodes': 234, 'total_num_leaves': 229, 'total_distance': 725, 'total_tree_height': 26}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM022-5_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM022 Visit=5 Part=1 depth=2 edges=12
#   SENT: と１０時でも１時間寝付けなかった３時間
# {'ID': 'UAM022', 'Visit': '5', 'Part': '1', 'max_nesting_relation': 5, 'max_nesting_depth': 2, 'total_nesting_depth': 37, 'max_tree_height': 5, 'total_num_nodes': 1104, 'total_num_leaves': 870, 'total_distance': 1325, 'total_tree_height': 378}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM020-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM020 Visit=1 Part=3 depth=1 edges=6
#   SENT: これは一番左の男の子が
# {'ID': 'UAM020', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 7, 'max_tree_height': 5, 'total_num_nodes': 177, 'total_num_leaves': 144, 'total_distance': 221, 'total_tree_height': 62}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM004-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM004 Visit=1 Part=1 depth=3 edges=61
#   SENT: んであの最初僕が障害者弁護士にあの頼んで一任していろいろ動いてもらったんですけどそれがもう７８年ぐらいたっても何の何のって０じゃないですけどほとんど動きがないっていうことであの先週僕のほうでもうしびれ切れちゃって
# {'ID': 'UTM004', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 37, 'max_nesting_depth': 3, 'total_nesting_depth': 199, 'max_tree_height': 10, 'total_num_nodes': 3960, 'total_num_leaves': 3720, 'total_distance': 9321, 'total_tree_height': 791}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM021-3_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM021 Visit=3 Part=2 depth=3 edges=24
#   SENT: こういうあの行ってからまた高山病にならないで何か訓練するとかって言ってましたね
# {'ID': 'UAM021', 'Visit': '3', 'Part': '2', 'max_nesting_relation': 10, 'max_nesting_depth': 3, 'total_nesting_depth': 68, 'max_tree_height': 6, 'total_num_nodes': 1351, 'total_num_leaves': 1211, 'total_distance': 2276, 'total_tree_height': 347}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM142-3_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM142 Visit=3 Part=1 depth=2 edges=29
#   SENT: そうすると他人がこうあれしててガタガタガタガタしてるのは正直言うとあの気持ちがいい悪いかするといい方ですね
# {'ID': 'UKM142', 'Visit': '3', 'Part': '1', 'max_nesting_relation': 11, 'max_nesting_depth': 2, 'total_nesting_depth': 100, 'max_tree_height': 6, 'total_num_nodes': 1928, 'total_num_leaves': 1721, 'total_distance': 3316, 'total_tree_height': 508}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM019-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM019 Visit=1 Part=2 depth=2 edges=38
#   SENT: このガラスの靴はただの靴に１２時になるとなってしまうので必ず１２時までに戻りなさいって言っておめかしをして行かせてくれた
# {'ID': 'UKM019', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 7, 'max_nesting_depth': 2, 'total_nesting_depth': 23, 'max_tree_height': 7, 'total_num_nodes': 489, 'total_num_leaves': 419, 'total_distance': 876, 'total_tree_height': 142}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM032-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM032 Visit=1 Part=3 depth=2 edges=66
#   SENT: ３人の子供たちがドーナツを食べるおやつの時間に２つずつ配られたんだけれども真ん中のお嬢さんのが１つなくなっちゃってあなた食べたでしょうって言うんですけども見当違いのほうに怒っていて食べた本人はケロッとしてる隣の男の子がいました
# {'ID': 'UKM032', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 14, 'max_nesting_depth': 2, 'total_nesting_depth': 11, 'max_tree_height': 9, 'total_num_nodes': 341, 'total_num_leaves': 324, 'total_distance': 993, 'total_tree_height': 59}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM168-1_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM168 Visit=1 Part=1 depth=3 edges=58
#   SENT: と会社はまあ一言で言うとヘルスケアをまあヘルスケアを生業としてる会社でま従業員のよく最近健康経営とかっていうのがキーワードとしてあると思うんですけどまあ従業員のそういった健康管理とか健康支援を
# {'ID': 'UKM168', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 24, 'max_nesting_depth': 3, 'total_nesting_depth': 99, 'max_tree_height': 9, 'total_num_nodes': 2141, 'total_num_leaves': 1975, 'total_distance': 4889, 'total_tree_height': 470}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM186-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM186 Visit=1 Part=2 depth=3 edges=29
#   SENT: でそのガラスの靴の持ち主を王子様が探しにいろんな街中を探し回ってでそのシンデレラを見つけてハッピーエンドっていう話
# {'ID': 'UKM186', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 15, 'max_nesting_depth': 3, 'total_nesting_depth': 11, 'max_tree_height': 8, 'total_num_nodes': 191, 'total_num_leaves': 182, 'total_distance': 527, 'total_tree_height': 35}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM012-4_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM012 Visit=4 Part=3 depth=2 edges=18
#   SENT: ってるんですがこの真ん中の女の子はこっちの子が食べたと思って
# {'ID': 'UKM012', 'Visit': '4', 'Part': '3', 'max_nesting_relation': 5, 'max_nesting_depth': 2, 'total_nesting_depth': 7, 'max_tree_height': 5, 'total_num_nodes': 141, 'total_num_leaves': 128, 'total_distance': 270, 'total_tree_height': 35}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM072-2_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM072 Visit=2 Part=3 depth=2 edges=28
#   SENT: で多分男の子は何か１個食べて１個かもうちょっとか食べてあとお皿には２個残っていて
# {'ID': 'UKM072', 'Visit': '2', 'Part': '3', 'max_nesting_relation': 12, 'max_nesting_depth': 2, 'total_nesting_depth': 16, 'max_tree_height': 7, 'total_num_nodes': 336, 'total_num_leaves': 311, 'total_distance': 804, 'total_tree_height': 74}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM059-2_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM059 Visit=2 Part=2 depth=2 edges=19
#   SENT: でそこにいとこたちが招かれてまあきれいに着飾って行くんだけども
# {'ID': 'UKM059', 'Visit': '2', 'Part': '2', 'max_nesting_relation': 21, 'max_nesting_depth': 2, 'total_nesting_depth': 17, 'max_tree_height': 8, 'total_num_nodes': 315, 'total_num_leaves': 302, 'total_distance': 880, 'total_tree_height': 57}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM094-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM094 Visit=1 Part=2 depth=1 edges=12
#   SENT: シンデレラ何か何かガラスの靴ガラスの靴ですか
# {'ID': 'UKM094', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 5, 'max_nesting_depth': 1, 'total_nesting_depth': 3, 'max_tree_height': 4, 'total_num_nodes': 83, 'total_num_leaves': 72, 'total_distance': 119, 'total_tree_height': 23}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UNM003-4_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UNM003 Visit=4 Part=1 depth=3 edges=24
#   SENT: 存在だったんですがまあ何何何一つ兄に勝てるようなことはなくちょっと劣等感を覚えるような
# {'ID': 'UNM003', 'Visit': '4', 'Part': '1', 'max_nesting_relation': 9, 'max_nesting_depth': 3, 'total_nesting_depth': 218, 'max_tree_height': 9, 'total_num_nodes': 4023, 'total_num_leaves': 3707, 'total_distance': 7790, 'total_tree_height': 906}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM025-4_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UMM025 Visit=4 Part=1 depth=2 edges=23
#   SENT: それであの１回先生があの合宿があるっていうのをチラシ持って来て２万３０００円だか
# {'ID': 'UMM025', 'Visit': '4', 'Part': '1', 'max_nesting_relation': 12, 'max_nesting_depth': 2, 'total_nesting_depth': 158, 'max_tree_height': 7, 'total_num_nodes': 3071, 'total_num_leaves': 2719, 'total_distance': 5335, 'total_tree_height': 814}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKP030-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UKP030 Visit=1 Part=3 depth=1 edges=45
# ...
# [MAX_NESTING_DEPTH] ID=UKM166 Visit=1 Part=1 depth=3 edges=22
#   SENT: それは倫理的にそれから正義感から当然子どもは守らなければいけないっていう気持ちも当然
# {'ID': 'UKM166', 'Visit': '1', 'Part': '1', 'max_nesting_relation': 10, 'max_nesting_depth': 3, 'total_nesting_depth': 125, 'max_tree_height': 6, 'total_num_nodes': 2658, 'total_num_leaves': 2397, 'total_distance': 4676, 'total_tree_height': 664}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM145-2_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM145 Visit=2 Part=2 depth=2 edges=17
#   SENT: で国中から若い娘を集めてパーティーをすることになったので
# {'ID': 'UKM145', 'Visit': '2', 'Part': '2', 'max_nesting_relation': 13, 'max_nesting_depth': 2, 'total_nesting_depth': 35, 'max_tree_height': 8, 'total_num_nodes': 630, 'total_num_leaves': 586, 'total_distance': 1255, 'total_tree_height': 142}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM188-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UKM188 Visit=1 Part=2 depth=2 edges=33
#   SENT: でと王子様とと出会ってで舞踏会に参加できたけどと夜中の１２時でち魔法が解けてしまうから慌てて帰って
# {'ID': 'UKM188', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 13, 'max_nesting_depth': 2, 'total_nesting_depth': 11, 'max_tree_height': 7, 'total_num_nodes': 188, 'total_num_leaves': 178, 'total_distance': 445, 'total_tree_height': 43}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM004-3_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM004 Visit=3 Part=3 depth=1 edges=8
#   SENT: と子供３人が多分長テーブルに
# {'ID': 'UAM004', 'Visit': '3', 'Part': '3', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 28, 'max_tree_height': 5, 'total_num_nodes': 471, 'total_num_leaves': 423, 'total_distance': 795, 'total_tree_height': 121}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM026-2_1Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM026 Visit=2 Part=1 depth=2 edges=19
#   SENT: まだまだこう不完全な感じっていうか笑える人生ではないかなっていうことで
# {'ID': 'UAM026', 'Visit': '2', 'Part': '1', 'max_nesting_relation': 7, 'max_nesting_depth': 2, 'total_nesting_depth': 41, 'max_tree_height': 6, 'total_num_nodes': 1354, 'total_num_leaves': 1132, 'total_distance': 1852, 'total_tree_height': 410}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM005-1_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM005 Visit=1 Part=2 depth=1 edges=18
#   SENT: シンデレラっては灰かぶり少女っていう意味だとかって読んだことあるんですけど
# {'ID': 'UAM005', 'Visit': '1', 'Part': '2', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 8, 'max_tree_height': 5, 'total_num_nodes': 196, 'total_num_leaves': 167, 'total_distance': 312, 'total_tree_height': 58}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM025-4_2Kana.txt
# [MAX_NESTING_DEPTH] ID=UAM025 Visit=4 Part=2 depth=1 edges=7
#   SENT: 男性に一目惚れしてしまいます
# {'ID': 'UAM025', 'Visit': '4', 'Part': '2', 'max_nesting_relation': 3, 'max_nesting_depth': 1, 'total_nesting_depth': 10, 'max_tree_height': 4, 'total_num_nodes': 349, 'total_num_leaves': 286, 'total_distance': 428, 'total_tree_height': 118}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM008-1_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UBM008 Visit=1 Part=3 depth=2 edges=12
#   SENT: このまだ３日か前４日前の人間かな
# {'ID': 'UBM008', 'Visit': '1', 'Part': '3', 'max_nesting_relation': 8, 'max_nesting_depth': 2, 'total_nesting_depth': 65, 'max_tree_height': 6, 'total_num_nodes': 1554, 'total_num_leaves': 1341, 'total_distance': 2385, 'total_tree_height': 448}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM008-5_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UTM008 Visit=5 Part=3 depth=3 edges=32
#   SENT: でそれを橋の上から見てる自転車に乗った男の子があの魚捕まってるよっていうふうに声かけてるっていうようなあの絵です
# {'ID': 'UTM008', 'Visit': '5', 'Part': '3', 'max_nesting_relation': 13, 'max_nesting_depth': 3, 'total_nesting_depth': 15, 'max_tree_height': 9, 'total_num_nodes': 245, 'total_num_leaves': 235, 'total_distance': 707, 'total_tree_height': 48}
# file: /home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM028-4_3Kana.txt
# [MAX_NESTING_DEPTH] ID=UBM028 Visit=4 Part=3 depth=2 edges=19
#   SENT: 息子さんはと犬はたこを揚げ息子さんはたこを揚げてで楽しんでいる
# {'ID': 'UBM028', 'Visit': '4', 'Part': '3', 'max_nesting_relation': 11, 'max_nesting_depth': 2, 'total_nesting_depth': 24, 'max_tree_height': 7, 'total_num_nodes': 430, 'total_num_leaves': 399, 'total_distance': 936, 'total_tree_height': 109}
#           ID Visit Part  max_nesting_relation  max_nesting_depth  \
# val   UBM028     4    3                    11                  2
# val   UTM008     5    3                    13                  3
# val   UBM008     1    3                     8                  2
# val   UAM025     4    2                     3                  1
# val   UAM005     1    2                     3                  1
# ..       ...   ...  ...                   ...                ...
# val   UTM018     1    1                    15                  4
# val   UMM020     2    1                     8                  2
# val   UKM057     1    3                    11                  2
# val   UMM029     3    2                     4                  2
# val  example     0    0                     0                  0
#
#      total_nesting_depth  max_tree_height  total_num_nodes  total_num_leaves  \
# val                 24.0              7.0            430.0             399.0
# val                 15.0              9.0            245.0             235.0
# val                 65.0              6.0           1554.0            1341.0
# val                 10.0              4.0            349.0             286.0
# val                  8.0              5.0            196.0             167.0
# ..                   ...              ...              ...               ...
# val                 79.0              7.0           1391.0            1268.0
# val                116.0              6.0           2792.0            2341.0
# val                  5.0              7.0            151.0             143.0
# val                 12.0              7.0            228.0             201.0
# val                  NaN              NaN              NaN               NaN
#
#      total_distance  total_tree_height
# val           936.0              109.0
# val           707.0               48.0
# val          2385.0              448.0
# val           428.0              118.0
# val           312.0               58.0
# ..              ...                ...
# val          2835.0              333.0
# val          3943.0              839.0
# val           481.0               31.0
# val           453.0               69.0
# val             NaN                NaN
#
# [3267 rows x 11 columns]
# TXT Files: ['/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM029-3_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM057-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM020-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM018-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM008-3_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM024-4_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM001-2_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM020-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM021-3_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM022-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM004-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM167-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM189-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM035-2_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM016-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM181-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM119-4_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKP029-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM040-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM139-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM085-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM048-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM029-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM201-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM021-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM025-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM015-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM036-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM011-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM049-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM212-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM042-4_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM019-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM062-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM004-4_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM122-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM078-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM025-3_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UNM003-3_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/USM001-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UNM002-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM024-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM070-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM072-5_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKP019-2_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM030-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM012-3_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM149-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg ...
# txtファイル数: 3266
# rest files(all-.txt): ['/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/.DS_Store', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/Dataframe_sBERT_R6Nov22.csv', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/Dataframe_analyzeNestedDependency_integration_R6_Apr28_RecordVoice_vf_CEJCminus.csv', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/Dataframe_analyzeNestedDependency_integration_R7Aug12_RecordVoice_vf_CEJCminus.csv', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/Dataframe_analyzeNestedDependency_parallel_R7Aug12_RecordVoice_vf_CEJCminus.csv']
# 実際に解析対象となったファイル数: 3267
# rest files(all-analyzed): []
# []
# TXT Files: ['/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM029-3_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM057-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM020-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM018-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM008-3_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM024-4_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM001-2_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM020-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UTM021-3_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UBM022-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM004-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM167-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM189-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM035-2_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM016-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM181-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM119-4_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKP029-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM040-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM139-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM085-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM048-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM029-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM201-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM021-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM025-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM015-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UGM036-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM011-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM049-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM212-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM042-4_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UOM019-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UAM062-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM004-4_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM122-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM078-2_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM025-3_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UNM003-3_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/USM001-1_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UNM002-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UMM024-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM070-1_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM072-5_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKP019-2_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM030-2_3Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM012-3_1Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/UKM149-1_2Kana.txt', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg ...
# txtファイル数: 3266
# rest files(all-.txt): ['/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/.DS_Store', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/Dataframe_sBERT_R6Nov22.csv', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/Dataframe_analyzeNestedDependency_integration_R6_Apr28_RecordVoice_vf_CEJCminus.csv', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/Dataframe_analyzeNestedDependency_integration_R7Aug12_RecordVoice_vf_CEJCminus.csv', '/home/hnakamura/nlp/nestedDependency/RecordVoice_yg_R6Nov22/Dataframe_analyzeNestedDependency_parallel_R7Aug12_RecordVoice_vf_CEJCminus.csv']
# 実際に解析対象となったファイル数: 3267
# rest files(all-analyzed): []
# 解析から外れたファイル数: 0
